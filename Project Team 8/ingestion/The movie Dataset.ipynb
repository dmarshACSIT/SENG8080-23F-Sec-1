# %%
import pypyodbc as odbc
import pyodbc

# %%
#setup to connect to database mysql server as per the server details
DRIVER_NAME = "SQL SERVER"
SERVER_NAME = "DESKTOP-99B9D8G\SQLEXPRESS"
DATABASE_NAME = "MOVIES_DB"

connection_string = f"""
    DRIVER={{{DRIVER_NAME}}};
    SERVER={SERVER_NAME};
    DATABASE={DATABASE_NAME};
    Trust_Connection=yes;
    uid=rahil;
    pwd=rahil;
"""

# %%
import requests
try:

    #api url
    url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

    #api headers
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0OGNlN2YwYTAyM2NiM2YzZjRlYjYwMjdjZmY0Zjg0ZiIsInN1YiI6IjY1MTVhOWZkOTNiZDY5MDExYjhjODljYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.70nPJD5UrTUTzRmnSLYpoUichOwWXd-jBiSH5CfMR8s"
        }

    #getting the response from the api
    response = requests.get(url, headers=headers)
    
    data = response.json()

    #connect to the database
    conn = odbc.connect(connection_string)

    print(conn)
    cursor = conn.cursor()
    cursor.execute("SELECT OBJECT_ID('movie_genres')")
    if cursor.fetchone()[0] is None:
        # Table does not exist, create it
        cursor.execute('''CREATE TABLE movie_genres (
                          id INT PRIMARY KEY,
                          genre_name NVARCHAR(255)
                        )''')

        print("Table 'movie_genres' created.")
        #logic here to store the data received from the api
    else:
        print("Table 'movie_genres' already exists.")
    
except pyodbc.Error as e:
    print(f"Database error: {str(e)}")
# Out:
# ...
# Table 'movie_genres' created.

# %%
#exploring the data from the received from the API in terms of columns

import requests
import json
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI0OGNlN2YwYTAyM2NiM2YzZjRlYjYwMjdjZmY0Zjg0ZiIsInN1YiI6IjY1MTVhOWZkOTNiZDY5MDExYjhjODljYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.70nPJD5UrTUTzRmnSLYpoUichOwWXd-jBiSH5CfMR8s"
}

response = requests.get(url, headers=headers)
data = response.json()

formatted_data = json.dumps(data, indent=4)

# Print the formatted data
print(formatted_data)
# Out:
# {
#     "page": 1,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/tmU7GeKVybMWFButWEGl2M4GeiP.jpg",
#             "genre_ids": [
#                 18,
#                 80
#             ],
#             "id": 238,
#             "original_language": "en",
#             "original_title": "The Godfather",
#             "overview": "Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.",
#             "popularity": 120.233,
#             "poster_path": "/3bhkrj58Vtu7enYsRolD1fZdja1.jpg",
#             "release_date": "1972-03-14",
#             "title": "The Godfather",
#             "video": false,
#             "vote_average": 8.7,
#             "vote_count": 18739
#         },
#         {
# ...
